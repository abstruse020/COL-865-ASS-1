# %%
# from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import pandas as pd
import numpy as np
import arff
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%time
traffic_db_path = '../Traffic_Violations/dataset.arff'
traffic_data = arff.load(open(traffic_db_path,'r'))

traffic_columns = [c[0] for c in traffic_data['attributes']]
print('columns',traffic_columns)

traffic_df = pd.DataFrame(traffic_data['data'], columns=traffic_columns)


traffic_df.head()
# Out:
# columns ['seqid', 'date_of_stop', 'time_of_stop', 'agency', 'subagency', 'description', 'location', 'latitude', 'longitude', 'accident', 'belts', 'personal_injury', 'property_damage', 'fatal', 'commercial_license', 'hazmat', 'commercial_vehicle', 'alcohol', 'work_zone', 'search_conducted', 'search_disposition', 'search_outcome', 'search_reason', 'search_reason_for_stop', 'search_type', 'search_arrest_reason', 'state', 'vehicletype', 'year', 'make', 'model', 'color', 'violation_type', 'charge', 'article', 'contributed_to_accident', 'race', 'gender', 'driver_city', 'driver_state', 'dl_state', 'arrest_type', 'geolocation']
# CPU times: user 1min 37s, sys: 3.93 s, total: 1min 41s
# Wall time: 1min 41s
#                                   seqid date_of_stop time_of_stop agency  \
# 0  fdcc1a6b-4854-4cde-bb60-248f478fa5b6   09/11/2019     09:56:00    MCP
# 1  842dad60-5edf-47a8-9e94-c7e6da729498   09/11/2019     09:42:00    MCP
# 2  4db837cc-f2fa-4a5b-9ac8-37698492b5f9   09/11/2019     09:36:00    MCP
# 3  79761295-50f6-4336-8b48-fdf55e87a326   09/11/2019     09:33:00    MCP
# 4  f9a7a508-386c-466e-95b2-dbf26d7d59fe   09/11/2019     09:30:00    MCP
#
#                  subagency                                        description  \
# 0   2nd District, Bethesda                                    STOP LIGHTS (*)
# 1  1st District, Rockville  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 2  1st District, Rockville  FAILURE VEH. TO YIELD INTERSECTION RIGHT-OF-WA...
# 3   2nd District, Bethesda  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 4    4th District, Wheaton       MOTOR VEH. W/O REQUIRED STOP LAMPS EQUIPMENT
#
#                            location   latitude  longitude accident  ...  \
# 0               27 @ SWEEPSTAKES RD  39.259627 -77.223760       No  ...
# 1         FREDERICK RD / REDLAND RD  39.112860 -77.162435       No  ...
# 2          S/B GEORGIA AVE AT MD200  39.117080 -77.068113       No  ...
# 3  OLD GEORGETOWN RD AT MCKINLEY ST  38.991630 -77.105873       No  ...
# 4       CONNECTICUT AVE / WELLER RD  39.064560 -77.073673       No  ...
#
#        charge                 article contributed_to_accident      race  \
# 0         64*                    None                   False  HISPANIC
# 1  21-201(a1)  Transportation Article                   False     BLACK
# 2      21-401  Transportation Article                   False     WHITE
# 3  21-201(a1)  Transportation Article                   False     BLACK
# 4   22-206(a)  Transportation Article                   False     BLACK
#
#   gender    driver_city driver_state dl_state          arrest_type  \
# 0      F       DAMASCUS           MD       MD  B - Unmarked Patrol
# 1      M   TEMPLE HILLS           MD       MD    A - Marked Patrol
# 2      M          OLNEY           MD       MD    A - Marked Patrol
# 3      F   GAITHERSBURG           MD       MD    A - Marked Patrol
# 4      F  SILVER SPRING           MD       MD    A - Marked Patrol
#
#                      geolocation
# 0  (39.2596266666667, -77.22376)
# 1         (39.11286, -77.162435)
# 2  (39.11708, -77.0681133333333)
# 3  (38.99163, -77.1058733333333)
# 4  (39.06456, -77.0736733333333)
#
# [5 rows x 43 columns]

# %%
''' details
Parse it-
date_of_stop - parse it into date
time_of_stop - parse it into time

Remove it-
agency -- just 1 value
description --  has sentences
model -- 19462  distinct values so whats the point
geolocation -- same as longitude and latitude

Fill None values --
location -- fill mean / new class
year -- 9647 missing attributes

Take None values as new class -
search_conducted -- 600828 missing attributes
search_disposition -- 1509055 missing attributes
search_outcome -- 619994 missing attributes
search_reason -- 1509055 missing attributes
search_reason_for_stop -- 600998 missing attributes
search_type -- 1509063 missing attributes
search_arrest_reason -- 1531303 missing attributes
state -- 59 missing attributes
make -- 9762 missing attributes
color -- 18657 missing attributes
article -- 76873 missing attributes
driver_city -- 387 missing attributes
driver_state -- 11 missing attributes
dl_state -- 929 missing attributes

Numeric Columns
date_of_stop, time_of_stop, latitude, longitude, year

Categorical Columns
subagency, location, accident, belts, personal_injury, property_damage, fatal, commercial_license, hazmat, commercial_vehicle, alcohol, work_zone, search_conducted, search_disposition, search_outcome, search_reason, search_reason_for_stop, search_type, search_arrest_reason, state, vehicletype, make, color, charge, article, contributed_to_accident, race, gender, driver_city, driver_state, dl_state, arrest_type


'''


remove_cols = ['agency','description','model',
'geolocation', 'location', 'driver_city']
fill_none_values_categorical = []
fill_none_values_numeric = ['year']
new_none_class = ['search_conducted', 'search_disposition', 'search_outcome', 'search_reason', 'search_reason_for_stop', 'search_type', 'search_arrest_reason', 'state', 'make', 'color', 'article', 'driver_state', 'dl_state']

categorical_cols = ['subagency', 'location', 'accident', 'belts', 'personal_injury', 'property_damage', 'fatal', 'commercial_license', 'hazmat', 'commercial_vehicle', 'alcohol', 'work_zone', 'search_conducted', 'search_disposition', 'search_outcome', 'search_reason', 'search_reason_for_stop', 'search_type', 'search_arrest_reason', 'state', 'vehicletype', 'make', 'color', 'charge', 'article', 'contributed_to_accident', 'race', 'gender', 'driver_state', 'dl_state', 'arrest_type']

numerical_cols = ['date_of_stop', 'time_of_stop', 'latitude', 'longitude', 'year']

all_missing_values_col = new_none_class + fill_none_values_categorical + fill_none_values_numeric

# %%
## uniformly distributed across these labels so removing the 4 columns

max_rows = traffic_df.shape[0]
print('max rows',max_rows)
remove_cols
for col in traffic_columns:
    
    if traffic_df[col].isna().sum() > 1000 and col not in numerical_cols:
        print(col,'None Count:',traffic_df[col].isna().sum())
        print( traffic_df[traffic_df[col].notna()].groupby('violation_type')['seqid'].count())
        print('-'*20)
        remove_cols.append(col)
        
## removing cols
print('cols to remove:', remove_cols)
traffic_df = traffic_df.drop(columns=remove_cols)

## adding None as a seperate class label
for col in new_none_class:
    if col not in remove_cols:
        print('col:', col)
        traffic_df[col] = traffic_df[col].fillna(value='None_class')
        
## categorical to ohe
traffic_df_dummy = traffic_df.copy()

for col in categorical_cols:
    print('col:', col)
    if col not in remove_cols and len(traffic_df[col].unique()) < 100:
        print('\tconvert to ohe')
        traffic_df = pd.concat([traffic_df.drop(columns=col),pd.get_dummies(traffic_df[col], prefix=col)], axis=1)
    elif col not in remove_cols and len(traffic_df[col].unique()) >= 100:
        print('\tdrop')
        traffic_df = traffic_df.drop(columns = col)
        remove_cols.append(col)
        
# fill none values  in numeric (i.e) year
# check all numeric are actually numeric already fixed
#parse date and time

for col in fill_none_values_numeric:
    traffic_df[col] = traffic_df[col].fillna(value=traffic_df[col].mean())

traffic_df['date_of_stop'] = pd.to_datetime(traffic_df['date_of_stop']).astype(int)/10e9
traffic_df['time_of_stop'] = pd.to_timedelta(traffic_df_dummy['time_of_stop']).astype(int)/10e9
# Out:
# max rows 1578154
# search_conducted None Count: 600828
# violation_type
# Citation    408912
# ESERO        56034
# SERO            14
# Warning     512366
# Name: seqid, dtype: int64
# --------------------
# search_disposition None Count: 1509055
# violation_type
# Citation    55357
# ESERO        1451
# SERO           10
# Warning     12281
# Name: seqid, dtype: int64
# --------------------
# search_outcome None Count: 619994
# violation_type
# Citation    389940
# ESERO        56028
# SERO            14
# Warning     512178
# Name: seqid, dtype: int64
# --------------------
# search_reason None Count: 1509055
# violation_type
# Citation    55357
# ESERO        1451
# SERO           10
# Warning     12281
# Name: seqid, dtype: int64
# --------------------
# search_reason_for_stop None Count: 600998
# violation_type
# Citation    408776
# ESERO        56028
# SERO            14
# Warning     512338
# Name: seqid, dtype: int64
# --------------------
# search_type None Count: 1509063
# violation_type
# Citation    55350
# ESERO        1451
# SERO           10
# Warning     12280
# Name: seqid, dtype: int64
# --------------------
# search_arrest_reason None Count: 1531303
# violation_type
# Citation    41114
# ESERO         761
# SERO            2
# Warning      4974
# Name: seqid, dtype: int64
# --------------------
# make None Count: 9762
# violation_type
# Citation    706938
# ESERO        75974
# SERO           899
# Warning     784581
# Name: seqid, dtype: int64
# --------------------
# model None Count: 9909
# violation_type
# Citation    706889
# ESERO        75967
# SERO           899
# Warning     784490
# Name: seqid, dtype: int64
# --------------------
# color None Count: 18657
# violation_type
# Citation    701339
# ESERO        75542
# SERO           888
# Warning     781728
# Name: seqid, dtype: int64
# --------------------
# article None Count: 76873
# violation_type
# Citation    711469
# Warning     789812
# Name: seqid, dtype: int64
# --------------------
# cols to remove: ['agency', 'description', 'model', 'geolocation', 'location', 'driver_city', 'search_conducted', 'search_disposition', 'search_outcome', 'search_reason', 'search_reason_for_stop', 'search_type', 'search_arrest_reason', 'make', 'model', 'color', 'article']
# col: state
# col: driver_state
# col: dl_state
# col: subagency
# 	convert to ohe
# col: location
# col: accident
# 	convert to ohe
# col: belts
# 	convert to ohe
# col: personal_injury
# 	convert to ohe
# col: property_damage
# 	convert to ohe
# col: fatal
# 	convert to ohe
# col: commercial_license
# 	convert to ohe
# col: hazmat
# 	convert to ohe
# col: commercial_vehicle
# 	convert to ohe
# col: alcohol
# 	convert to ohe
# col: work_zone
# 	convert to ohe
# col: search_conducted
# col: search_disposition
# col: search_outcome
# col: search_reason
# col: search_reason_for_stop
# col: search_type
# col: search_arrest_reason
# col: state
# 	convert to ohe
# col: vehicletype
# 	convert to ohe
# col: make
# col: color
# col: charge
# 	drop
# col: article
# col: contributed_to_accident
# 	convert to ohe
# col: race
# 	convert to ohe
# col: gender
# 	convert to ohe
# col: driver_state
# 	convert to ohe
# col: dl_state
# 	convert to ohe
# col: arrest_type
# 	convert to ohe

# %%
## making duplicate row if dataset only has 1 row for given class
label_grp_df = traffic_df.groupby('violation_type')
min_label_size = 2
test_size = 0.2
small_sized_labels = []
small_sized_labels_df = pd.DataFrame(columns=traffic_df.columns)
# y_df = pd.get_dummies(traffic_df.iloc[:,-1])
train_df = pd.DataFrame(columns=traffic_df.columns)
test_df = pd.DataFrame(columns=traffic_df.columns)

for grp_label, grp in label_grp_df:
    grp_size = len(grp)
    print(grp_label, grp_size)
    if grp_size < min_label_size:
        small_sized_labels.append(grp_label)
        #print(f'grp:{grp}')
        for row in grp.iterrows():
            #print('row',row[1])
            small_sized_labels_df = small_sized_labels_df.append(row[1], ignore_index=True)
            train_df = train_df.append(row[1], ignore_index=True)
            test_df = test_df.append(row[1], ignore_index=True)
    else:
        temp_train, temp_test = train_test_split(grp, test_size=0.2)
        print(f'\t temp_train size:{temp_train.shape}, temp_test size:{temp_test.shape}')
        train_df = pd.concat([train_df, temp_train], ignore_index=True)
        test_df = pd.concat([test_df, temp_test], ignore_index=True)
        
print(f'\nsmall sized labels:{small_sized_labels}')
train_df = train_df.sample(frac=1)
test_df = test_df.sample(frac=1)
small_sized_labels_df
# Out:
# Citation 711469
# 	 temp_train size:(569175, 310), temp_test size:(142294, 310)
# ESERO 75974
# 	 temp_train size:(60779, 310), temp_test size:(15195, 310)
# SERO 899
# 	 temp_train size:(719, 310), temp_test size:(180, 310)
# Warning 789812
# 	 temp_train size:(631849, 310), temp_test size:(157963, 310)
#
# small sized labels:[]
# Empty DataFrame
# Columns: [seqid, date_of_stop, time_of_stop, latitude, longitude, year, violation_type, subagency_1st District, Rockville, subagency_2nd District, Bethesda, subagency_3rd District, Silver Spring, subagency_4th District, Wheaton, subagency_5th District, Germantown, subagency_6th District, Gaithersburg / Montgomery Village, subagency_Headquarters and Special Operations, subagency_S15, subagency_W15, accident_No, accident_Yes, belts_No, belts_Yes, personal_injury_No, personal_injury_Yes, property_damage_No, property_damage_Yes, fatal_No, fatal_Yes, commercial_license_No, commercial_license_Yes, hazmat_No, hazmat_Yes, commercial_vehicle_No, commercial_vehicle_Yes, alcohol_No, alcohol_Yes, work_zone_No, work_zone_Yes, state_AB, state_AK, state_AL, state_AR, state_AS, state_AZ, state_BC, state_CA, state_CO, state_CT, state_DC, state_DE, state_FL, state_GA, state_GU, state_HI, state_IA, state_ID, state_IL, state_IN, state_IT, state_KS, state_KY, state_LA, state_MA, state_MB, state_MD, state_ME, state_MH, state_MI, state_MN, state_MO, state_MS, state_MT, state_NB, state_NC, state_ND, state_NE, state_NF, state_NH, state_NJ, state_NM, state_NS, state_NV, state_NY, state_None_class, state_OH, state_OK, state_ON, state_OR, state_PA, state_PE, state_PQ, state_PR, state_QC, state_RI, state_SC, state_SD, state_SK, state_TN, state_TX, state_US, state_UT, state_VA, ...]
# Index: []
#
# [0 rows x 310 columns]

# %%
X_train = train_df.drop(columns=['seqid', 'violation_type'])
y_train_non_ohe = train_df['violation_type']
y_train = pd.get_dummies(train_df['violation_type'])
X_test = test_df.drop(columns=['seqid', 'violation_type'])
y_test_non_ohe = test_df['violation_type']
y_test = pd.get_dummies(test_df['violation_type'])
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1262522, 308) (1262522, 4)
# (315632, 308) (315632, 4)

# %%
X_train
# Out:
#         date_of_stop time_of_stop   latitude  longitude    year  \
# 465604   139147200.0       2874.0  39.052572 -76.993817  2005.0
# 853753   139363200.0       8280.0  39.090967 -77.043515  2003.0
# 1097250  136088640.0       5928.0  39.124906   -77.1612  2009.0
# 684671   145152000.0       7146.0  39.068508 -77.129678  2014.0
# 1182758  138274560.0        114.0  39.105648 -77.076385  2006.0
# ...              ...          ...        ...        ...     ...
# 1070760  153973440.0       4122.0  39.048078   -76.9831  2014.0
# 530449   142801920.0       7236.0  39.275265 -77.216088  2001.0
# 677532   145946880.0       7344.0  39.132475 -77.070605  2006.0
# 861676   148435200.0        588.0  39.071832 -76.954557  2003.0
# 320734   136771200.0       1140.0  39.173018  -77.28361  1996.0
#
#         subagency_1st District, Rockville subagency_2nd District, Bethesda  \
# 465604                                  0                                0
# 853753                                  0                                0
# 1097250                                 1                                0
# 684671                                  1                                0
# 1182758                                 0                                0
# ...                                   ...                              ...
# 1070760                                 0                                0
# 530449                                  0                                0
# 677532                                  0                                0
# 861676                                  0                                0
# 320734                                  0                                0
#
#         subagency_3rd District, Silver Spring subagency_4th District, Wheaton  \
# 465604                                      1                               0
# 853753                                      0                               1
# 1097250                                     0                               0
# 684671                                      0                               0
# 1182758                                     0                               1
# ...                                       ...                             ...
# 1070760                                     1                               0
# 530449                                      0                               0
# 677532                                      0                               1
# 861676                                      1                               0
# 320734                                      0                               0
#
#         subagency_5th District, Germantown  ...  \
# 465604                                   0  ...
# 853753                                   0  ...
# 1097250                                  0  ...
# 684671                                   0  ...
# 1182758                                  0  ...
# ...                                    ...  ...
# 1070760                                  0  ...
# 530449                                   1  ...
# 677532                                   0  ...
# 861676                                   0  ...
# 320734                                   1  ...
#
#         arrest_type_J - Unmarked Moving Radar (Moving)  \
# 465604                                               0
# 853753                                               0
# 1097250                                              0
# 684671                                               0
# 1182758                                              0
# ...                                                ...
# 1070760                                              0
# 530449                                               0
# 677532                                               0
# 861676                                               0
# 320734                                               0
#
#         arrest_type_K - Aircraft Assist arrest_type_L - Motorcycle  \
# 465604                                0                          0
# 853753                                0                          0
# 1097250                               0                          0
# 684671                                0                          0
# 1182758                               0                          0
# ...                                 ...                        ...
# 1070760                               0                          0
# 530449                                0                          0
# 677532                                0                          0
# 861676                                0                          0
# 320734                                0                          0
#
#         arrest_type_M - Marked (Off-Duty) arrest_type_N - Unmarked (Off-Duty)  \
# 465604                                  0                                   0
# 853753                                  0                                   0
# 1097250                                 0                                   0
# 684671                                  0                                   0
# 1182758                                 0                                   0
# ...                                   ...                                 ...
# 1070760                                 0                                   0
# 530449                                  0                                   0
# 677532                                  0                                   0
# 861676                                  0                                   0
# 320734                                  0                                   0
#
#         arrest_type_O - Foot Patrol arrest_type_P - Mounted Patrol  \
# 465604                            0                              0
# 853753                            0                              0
# 1097250                           0                              0
# 684671                            0                              0
# 1182758                           0                              0
# ...                             ...                            ...
# 1070760                           0                              0
# 530449                            0                              0
# 677532                            0                              0
# 861676                            0                              0
# 320734                            0                              0
#
#         arrest_type_Q - Marked Laser arrest_type_R - Unmarked Laser  \
# 465604                             1                              0
# 853753                             0                              0
# 1097250                            0                              0
# 684671                             0                              0
# 1182758                            0                              0
# ...                              ...                            ...
# 1070760                            0                              0
# 530449                             0                              0
# 677532                             0                              0
# 861676                             0                              0
# 320734                             0                              0
#
#         arrest_type_S - License Plate Recognition
# 465604                                          0
# 853753                                          0
# 1097250                                         0
# 684671                                          0
# 1182758                                         0
# ...                                           ...
# 1070760                                         0
# 530449                                          0
# 677532                                          0
# 861676                                          0
# 320734                                          0
#
# [1262522 rows x 308 columns]

# %%
for col in X_train.columns:
    print(X_train[col].dtype)
# Out:
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.dtype
# Out:
# dtype('float64')

# %%
y_train.values.astype(int).dtype
# Out:
# dtype('int64')

# %%
for col in traffic_df.columns:
    print(traffic_df[col].dtype)
    if traffic_df[col].dtype == object:
        print('\t',col)
# Out:
# object
# 	 seqid
# float64
# float64
# float64
# float64
# float64
# object
# 	 violation_type
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8

# %%
# %%time
from sklearn.ensemble import BaggingRegressor, BaggingClassifier
from sklearn.model_selection import cross_val_score

from scikit_obliquetree.HHCART import HouseHolderCART, HHCARTNode
from scikit_obliquetree.segmentor import MSE, MeanSegmentor, ABCMeta

# clf = BaggingClassifier(
#         HHCARTNode(ABCMeta(), MeanSegmentor(), max_depth=3),
#         n_estimators=100,
#         n_jobs=-1
# )

reg = BaggingRegressor(
    HouseHolderCART(MSE(), MeanSegmentor(), max_depth=20),
    n_estimators=50,
    n_jobs=-1,
)
# Out:
# CPU times: user 55.5 ms, sys: 12.1 ms, total: 67.6 ms
# Wall time: 67.3 ms

# %%
# %%time
reg.fit(X_train, np.argmax(y_train.values, axis=1))
# Out:
# CPU times: user 12min 3s, sys: 5min 6s, total: 17min 9s
# Wall time: 2h 18min 4s
# BaggingRegressor(base_estimator=HouseHolderCART(impurity=<scikit_obliquetree.segmentor.MSE object at 0x7f8529aea370>,
#                                                 segmentor=<scikit_obliquetree.segmentor.MeanSegmentor object at 0x7f8529aea250>),
#                  n_estimators=50, n_jobs=-1)

# %%
# %%time
y_train_pred = reg.predict(X_train)
accuracy_score(np.argmax(y_train.values, axis=1), np.round(y_train_pred).astype('int'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:2, in <module>
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:211, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     145 """Accuracy classification score.
#     146
#     147 In multilabel classification, this function computes subset accuracy:
#    (...)
#     207 0.5
#     208 """
#     210 # Compute accuracy for each possible representation
# --> 211 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212 check_consistent_length(y_true, y_pred, sample_weight)
#     213 if y_type.startswith("multilabel"):
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:84, in _check_targets(y_true, y_pred)
#      57 def _check_targets(y_true, y_pred):
#      58     """Check that y_true and y_pred belong to the same classification task.
#      59
#      60     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:329, in check_consistent_length(*arrays)
#     318 def check_consistent_length(*arrays):
#     319     """Check that all arrays have consistent first dimensions.
#     320
#     321     Checks whether all objects in arrays have the same shape or length.
#    (...)
#     326         Objects that will be checked for consistent length.
#     327     """
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:329, in <listcomp>(.0)
#     318 def check_consistent_length(*arrays):
#     319     """Check that all arrays have consistent first dimensions.
#     320
#     321     Checks whether all objects in arrays have the same shape or length.
#    (...)
#     326         Objects that will be checked for consistent length.
#     327     """
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:269, in _num_samples(x)
#     267 if hasattr(x, "shape") and x.shape is not None:
#     268     if len(x.shape) == 0:
# --> 269         raise TypeError(
#     270             "Singleton array %r cannot be considered a valid collection." % x
#     271         )
#     272     # Check that shape is returning an integer or default to len
#     273     # Dask dataframes may not return numeric shape[0] value
#     274     if isinstance(x.shape[0], numbers.Integral):
#
# TypeError: Singleton array 0 cannot be considered a valid collection.

# %%
# %%time
y_test_pred = reg.predict(X_test)
accuracy_score(np.argmax(y_test.values, axis=1), np.round(y_test_pred).astype('int'))
# Out:
# /home/harshpandey/anaconda3/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# CPU times: user 12min 58s, sys: 6min 6s, total: 19min 4s
# Wall time: 20min 48s
# 0.4635366502762711

# %%
test_cnf_matrix = confusion_matrix(np.argmax(y_test.values, axis=1), np.round(y_test_pred).astype('int'))
plt.figure(figsize=(15,12))
test_cnf_df = pd.DataFrame(test_cnf_matrix, index= range(4), columns=range(4))
# sns.heatmap(np.log(test_cnf_df+1), annot=True)
sns.heatmap(np.log2(test_cnf_df+1), annot=True)
# sns.heatmap(test_cnf_df, annot=True)
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title("Log Correlation matrix of test")
plt.savefig('Oblique_t_traffic_test.png')

# %%
print()

# %%
savefig
